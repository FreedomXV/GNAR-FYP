# %%
import pandas as pd
import numpy as np
from shapely.wkt import loads
from scipy.spatial import KDTree

# %%
stations = pd.read_csv('Data/NYC Data/MTA_Subway_Stations_20250124.csv')  # NYC subway stations
pois = pd.read_csv("Data/NYC Data/Points_of_Interest_20250124.csv")          # Points of interest

# %%
stations.head()
# Out:
#   GTFS Stop ID  Station ID  Complex ID Division     Line  \
# 0          R01           1           1      BMT  Astoria
# 1          R03           2           2      BMT  Astoria
# 2          R04           3           3      BMT  Astoria
# 3          R05           4           4      BMT  Astoria
# 4          R06           5           5      BMT  Astoria
#
#               Stop Name Borough    CBD Daytime Routes Structure  \
# 0  Astoria-Ditmars Blvd       Q  False            N W  Elevated
# 1          Astoria Blvd       Q  False            N W  Elevated
# 2                 30 Av       Q  False            N W  Elevated
# 3              Broadway       Q  False            N W  Elevated
# 4                 36 Av       Q  False            N W  Elevated
#
#    GTFS Latitude  GTFS Longitude North Direction Label South Direction Label  \
# 0      40.775036      -73.912034             Last Stop             Manhattan
# 1      40.770258      -73.917843               Astoria             Manhattan
# 2      40.766779      -73.921479               Astoria             Manhattan
# 3      40.761820      -73.925508               Astoria             Manhattan
# 4      40.756804      -73.929575               Astoria             Manhattan
#
#    ADA  ADA Northbound  ADA Southbound ADA Notes                  Georeference
# 0    0               0               0       NaN  POINT (-73.912034 40.775036)
# 1    1               1               1       NaN  POINT (-73.917843 40.770258)
# 2    0               0               0       NaN  POINT (-73.921479 40.766779)
# 3    0               0               0       NaN   POINT (-73.925508 40.76182)
# 4    0               0               0       NaN  POINT (-73.929575 40.756804)

# %%
pois.head()
# Out:
#                                         the_geom  SEGMENTID  COMPLEXID  \
# 0  POINT (-74.00701717096757 40.724634757833414)      31895          0
# 1  POINT (-73.82661642130311 40.797182526598505)     306303       3378
# 2   POINT (-73.99395441100663 40.70384707235758)     144842       3960
# 3    POINT (-73.9919414213091 40.70960010711745)     162664          0
# 4    POINT (-73.9526609766105 40.73906602249743)     157362          0
#
#   SAFTYPE  SOS  PLACEID  FACI_DOM  BIN  BOROUGH                 CREATED  \
# 0       N  1.0      567         9    0      1.0  05/14/2009 12:00:00 AM
# 1       N  2.0      568         8    0      4.0  05/14/2009 12:00:00 AM
# 2       N  2.0      576         8    0      3.0  05/14/2009 12:00:00 AM
# 3       N  1.0      580         8    0      1.0  05/14/2009 12:00:00 AM
# 4       N  1.0      582         8    0      3.0  05/14/2009 12:00:00 AM
#
#                  MODIFIED  FACILITY_T SOURCE        B7SC  PRI_ADD        NAME
# 0  11/18/2011 12:00:00 AM           6  DoITT  19743001.0        0     HOLLAND
# 1  01/09/2017 12:00:00 AM           6  DoITT  49731001.0        0  WHITESTONE
# 2  01/22/2018 12:00:00 AM           6  DoITT  39734001.0        0    BROOKLYN
# 3  05/11/2011 12:00:00 AM           6  DoITT  19795001.0        0   MANHATTAN
# 4  03/03/2017 12:00:00 AM           6  DoITT  39740001.0        0     PULASKI

# %%
# Convert the geometry column to Shapely Point objects
stations['Georeference'] = stations['Georeference'].apply(loads)

# Extract latitude and longitude from Shapely Point objects
stations['latitude'] = stations['Georeference'].apply(lambda point: point.y)
stations['longitude'] = stations['Georeference'].apply(lambda point: point.x)

# Convert to NumPy array
station_coords = stations[['latitude', 'longitude']].to_numpy()

# %%
# Convert the geometry column to Shapely Point objects
pois['the_geom'] = pois['the_geom'].apply(loads)

# Extract latitude and longitude from Shapely Point objects
pois['latitude'] = pois['the_geom'].apply(lambda point: point.y)
pois['longitude'] = pois['the_geom'].apply(lambda point: point.x)

# Convert to NumPy array
poi_coords = pois[['latitude', 'longitude']].to_numpy()

# %%
# Build a KDTree for stations
tree = KDTree(station_coords)

# %%
# Query the KDTree for each POI to find the closest station
distances, indices = tree.query(poi_coords)

# %%
# Add results back to the POI DataFrame
pois['closest_station_id'] = stations.iloc[indices]['Station ID'].values
pois['closest_complex_id'] = stations.iloc[indices]['Complex ID'].values
pois['closest_station_name'] = stations.iloc[indices]['Stop Name'].values
pois['distance_to_station'] = distances  # Approx Cartesian distance

# %%
pois.head()
# Out:
#                                         the_geom  SEGMENTID  COMPLEXID  \
# 0  POINT (-74.00701717096757 40.724634757833414)      31895          0
# 1  POINT (-73.82661642130311 40.797182526598505)     306303       3378
# 2   POINT (-73.99395441100663 40.70384707235758)     144842       3960
# 3    POINT (-73.9919414213091 40.70960010711745)     162664          0
# 4    POINT (-73.9526609766105 40.73906602249743)     157362          0
#
#   SAFTYPE  SOS  PLACEID  FACI_DOM  BIN  BOROUGH                 CREATED  ...  \
# 0       N  1.0      567         9    0      1.0  05/14/2009 12:00:00 AM  ...
# 1       N  2.0      568         8    0      4.0  05/14/2009 12:00:00 AM  ...
# 2       N  2.0      576         8    0      3.0  05/14/2009 12:00:00 AM  ...
# 3       N  1.0      580         8    0      1.0  05/14/2009 12:00:00 AM  ...
# 4       N  1.0      582         8    0      3.0  05/14/2009 12:00:00 AM  ...
#
#   SOURCE        B7SC PRI_ADD        NAME   latitude  longitude  \
# 0  DoITT  19743001.0       0     HOLLAND  40.724635 -74.007017
# 1  DoITT  49731001.0       0  WHITESTONE  40.797183 -73.826616
# 2  DoITT  39734001.0       0    BROOKLYN  40.703847 -73.993954
# 3  DoITT  19795001.0       0   MANHATTAN  40.709600 -73.991941
# 4  DoITT  39740001.0       0     PULASKI  40.739066 -73.952661
#
#    closest_station_id  closest_complex_id    closest_station_name  \
# 0                 325                 325                Canal St
# 1                 447                 447        Flushing-Main St
# 2                 173                 173                 High St
# 3                 234                 234           East Broadway
# 4                 464                 464  Vernon Blvd-Jackson Av
#
#    distance_to_station
# 0             0.001928
# 1             0.037737
# 2             0.005662
# 3             0.004479
# 4             0.003677
#
# [5 rows x 22 columns]
