# %%
# ## Test with pdf_tables API
# import pdftables_api

# # API KEY VERIFICATION
# conversion = pdftables_api.Client('API KEY')

# # PDf to CSV 
# # (Hello.pdf, Hello)
# conversion.csv(pdf_file_path, output_file_path)

# %%
## Test with tabula-py
# pip install tabula-py
# https://tabula-py.readthedocs.io/en/latest/
# https://pypi.org/project/tabula-py/

import tabula

# use tabula.convert_into for single files
# tabula.convert_into("PDF Bulletins/2025_week_22.pdf", "PDF Bulletins/2025_week_22_test.csv", output_format="csv", pages=1, lattice=True)

# use tabula.convert_into_by_batch to run through a whole folder
tabula.convert_into_by_batch("PDF Bulletins/", output_format='csv', pages=1, lattice=True)
# Out:
# Got stderr: Jul 03, 2025 9:11:14 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Jul 03, 2025 9:11:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Jul 03, 2025 9:11:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Jul 03, 2025 9:11:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Jul 03, 2025 9:11:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# ...

# %%
df = tabula.read_pdf('PDF Bulletins/2025_week_22.pdf', pages = 1, lattice = True)

# %%
df[0]
# Out:
#                                        Unnamed: 0      E Week          22  \
# 0                                             NaN        2025        2024
# 1                                             NaN  2020 -2024  2020 -2024
# 2                       FOOD/WATER-BORNE DISEASES         NaN         NaN
# 3                               Acute Hepatitis A           1           1
# 4                               Acute Hepatitis E           4           1
# 5                              Campylobacteriosis          14           7
# 6                                         Cholera           0           0
# 7                                     Paratyphoid           1           1
# 8                                   Poliomyelitis           0           0
# 9                                   Salmonellosis          39          38
# 10                                        Typhoid           0           1
# 11                          VECTOR-BORNE DISEASES         NaN         NaN
# ...
